# %% [markdown]
# <a href="https://colab.research.google.com/github/BishalDas1010/BIT_project_TInyML/blob/main/BIT_test_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile

zip_file = "/content/drive/MyDrive/Dataset_For_Bit/human+activity+recognition+using+smartphones (1).zip"  # Your ZIP file

with zipfile.ZipFile(zip_file, "r") as zip_ref:
    zip_ref.extractall("extracted_files")

print("ZIP extracted successfully!")
# Out:
# ZIP extracted successfully!

# %%
location = "/content/extracted_files/UCI HAR Dataset.zip"
with zipfile.ZipFile(location, "r") as zip_ref:
    zip_ref.extractall("extracted_files")

print("ZIP extracted successfully!")
# Out:
# ZIP extracted successfully!

# %%
#just chack it is  X tran values
df_X = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt",
    sep=r'\s+',
    header=None
)
df_X.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.000181  0.010139  0.009276  0.005066  0.010810  0.004045  0.004757
# 1  0.001094  0.004550  0.002879  0.002247  0.003305  0.002416  0.001619
# 2  0.003531  0.002285 -0.000420 -0.003738 -0.006706 -0.003148  0.000733
# 3 -0.001772 -0.001311  0.000388  0.000408 -0.000355  0.000998  0.001109
# 4  0.000087 -0.000272  0.001022  0.003126  0.002284  0.000885  0.001933
#
#         7         8         9    ...       118       119       120       121  \
# 0  0.006214  0.003307  0.007572  ...  0.001412 -0.001509  0.000060  0.000435
# 1  0.000981  0.000009 -0.000363  ... -0.000104 -0.000141  0.001333  0.001541
# 2  0.000668  0.002162 -0.000946  ...  0.000661  0.001853 -0.000268 -0.000394
# 3 -0.003149 -0.008882 -0.010483  ...  0.000458  0.002103  0.001358  0.000820
# 4  0.002270  0.002247  0.002175  ...  0.002529  0.003518 -0.000248 -0.002761
#
#         122       123       124       125       126       127
# ...

# %%
#just chack it is  X tran values
df_X = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt",
    sep=r'\s+',
    header=None
)
df_X.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.000181  0.010139  0.009276  0.005066  0.010810  0.004045  0.004757
# 1  0.001094  0.004550  0.002879  0.002247  0.003305  0.002416  0.001619
# 2  0.003531  0.002285 -0.000420 -0.003738 -0.006706 -0.003148  0.000733
# 3 -0.001772 -0.001311  0.000388  0.000408 -0.000355  0.000998  0.001109
# 4  0.000087 -0.000272  0.001022  0.003126  0.002284  0.000885  0.001933
#
#         7         8         9    ...       118       119       120       121  \
# 0  0.006214  0.003307  0.007572  ...  0.001412 -0.001509  0.000060  0.000435
# 1  0.000981  0.000009 -0.000363  ... -0.000104 -0.000141  0.001333  0.001541
# 2  0.000668  0.002162 -0.000946  ...  0.000661  0.001853 -0.000268 -0.000394
# 3 -0.003149 -0.008882 -0.010483  ...  0.000458  0.002103  0.001358  0.000820
# 4  0.002270  0.002247  0.002175  ...  0.002529  0.003518 -0.000248 -0.002761
#
#         122       123       124       125       126       127
# ...

# %%
#just chack it is  X tran values
df_X = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt",
    sep=r'\s+',
    header=None
)
df_X.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.000181  0.010139  0.009276  0.005066  0.010810  0.004045  0.004757
# 1  0.001094  0.004550  0.002879  0.002247  0.003305  0.002416  0.001619
# 2  0.003531  0.002285 -0.000420 -0.003738 -0.006706 -0.003148  0.000733
# 3 -0.001772 -0.001311  0.000388  0.000408 -0.000355  0.000998  0.001109
# 4  0.000087 -0.000272  0.001022  0.003126  0.002284  0.000885  0.001933
#
#         7         8         9    ...       118       119       120       121  \
# 0  0.006214  0.003307  0.007572  ...  0.001412 -0.001509  0.000060  0.000435
# 1  0.000981  0.000009 -0.000363  ... -0.000104 -0.000141  0.001333  0.001541
# 2  0.000668  0.002162 -0.000946  ...  0.000661  0.001853 -0.000268 -0.000394
# 3 -0.003149 -0.008882 -0.010483  ...  0.000458  0.002103  0.001358  0.000820
# 4  0.002270  0.002247  0.002175  ...  0.002529  0.003518 -0.000248 -0.002761
#
#         122       123       124       125       126       127
# ...

# %%
#just chack it is  X tran values
df_X = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt",
    sep=r'\s+',
    header=None
)
df_X.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.000181  0.010139  0.009276  0.005066  0.010810  0.004045  0.004757
# 1  0.001094  0.004550  0.002879  0.002247  0.003305  0.002416  0.001619
# 2  0.003531  0.002285 -0.000420 -0.003738 -0.006706 -0.003148  0.000733
# 3 -0.001772 -0.001311  0.000388  0.000408 -0.000355  0.000998  0.001109
# 4  0.000087 -0.000272  0.001022  0.003126  0.002284  0.000885  0.001933
#
#         7         8         9    ...       118       119       120       121  \
# 0  0.006214  0.003307  0.007572  ...  0.001412 -0.001509  0.000060  0.000435
# 1  0.000981  0.000009 -0.000363  ... -0.000104 -0.000141  0.001333  0.001541
# 2  0.000668  0.002162 -0.000946  ...  0.000661  0.001853 -0.000268 -0.000394
# 3 -0.003149 -0.008882 -0.010483  ...  0.000458  0.002103  0.001358  0.000820
# 4  0.002270  0.002247  0.002175  ...  0.002529  0.003518 -0.000248 -0.002761
#
#         122       123       124       125       126       127
# ...

# %%
#just chack it is  X tran values
df_X = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt",
    sep=r'\s+',
    header=None
)
df_X.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.000181  0.010139  0.009276  0.005066  0.010810  0.004045  0.004757
# 1  0.001094  0.004550  0.002879  0.002247  0.003305  0.002416  0.001619
# 2  0.003531  0.002285 -0.000420 -0.003738 -0.006706 -0.003148  0.000733
# 3 -0.001772 -0.001311  0.000388  0.000408 -0.000355  0.000998  0.001109
# 4  0.000087 -0.000272  0.001022  0.003126  0.002284  0.000885  0.001933
#
#         7         8         9    ...       118       119       120       121  \
# 0  0.006214  0.003307  0.007572  ...  0.001412 -0.001509  0.000060  0.000435
# 1  0.000981  0.000009 -0.000363  ... -0.000104 -0.000141  0.001333  0.001541
# 2  0.000668  0.002162 -0.000946  ...  0.000661  0.001853 -0.000268 -0.000394
# 3 -0.003149 -0.008882 -0.010483  ...  0.000458  0.002103  0.001358  0.000820
# 4  0.002270  0.002247  0.002175  ...  0.002529  0.003518 -0.000248 -0.002761
#
#         122       123       124       125       126       127
# ...

# %%
#just chack it is  X tran values
df_X = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt",
    sep=r'\s+',
    header=None
)
df_X.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.000181  0.010139  0.009276  0.005066  0.010810  0.004045  0.004757
# 1  0.001094  0.004550  0.002879  0.002247  0.003305  0.002416  0.001619
# 2  0.003531  0.002285 -0.000420 -0.003738 -0.006706 -0.003148  0.000733
# 3 -0.001772 -0.001311  0.000388  0.000408 -0.000355  0.000998  0.001109
# 4  0.000087 -0.000272  0.001022  0.003126  0.002284  0.000885  0.001933
#
#         7         8         9    ...       118       119       120       121  \
# 0  0.006214  0.003307  0.007572  ...  0.001412 -0.001509  0.000060  0.000435
# 1  0.000981  0.000009 -0.000363  ... -0.000104 -0.000141  0.001333  0.001541
# 2  0.000668  0.002162 -0.000946  ...  0.000661  0.001853 -0.000268 -0.000394
# 3 -0.003149 -0.008882 -0.010483  ...  0.000458  0.002103  0.001358  0.000820
# 4  0.002270  0.002247  0.002175  ...  0.002529  0.003518 -0.000248 -0.002761
#
#         122       123       124       125       126       127
# ...

# %%
#just chack it is  X tran values
df_X = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt",
    sep=r'\s+',
    header=None
)
df_X.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.000181  0.010139  0.009276  0.005066  0.010810  0.004045  0.004757
# 1  0.001094  0.004550  0.002879  0.002247  0.003305  0.002416  0.001619
# 2  0.003531  0.002285 -0.000420 -0.003738 -0.006706 -0.003148  0.000733
# 3 -0.001772 -0.001311  0.000388  0.000408 -0.000355  0.000998  0.001109
# 4  0.000087 -0.000272  0.001022  0.003126  0.002284  0.000885  0.001933
#
#         7         8         9    ...       118       119       120       121  \
# 0  0.006214  0.003307  0.007572  ...  0.001412 -0.001509  0.000060  0.000435
# 1  0.000981  0.000009 -0.000363  ... -0.000104 -0.000141  0.001333  0.001541
# 2  0.000668  0.002162 -0.000946  ...  0.000661  0.001853 -0.000268 -0.000394
# 3 -0.003149 -0.008882 -0.010483  ...  0.000458  0.002103  0.001358  0.000820
# 4  0.002270  0.002247  0.002175  ...  0.002529  0.003518 -0.000248 -0.002761
#
#         122       123       124       125       126       127
# ...

# %%
#just chack it is  X tran values
df_X = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt",
    sep=r'\s+',
    header=None
)
df_X.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.000181  0.010139  0.009276  0.005066  0.010810  0.004045  0.004757
# 1  0.001094  0.004550  0.002879  0.002247  0.003305  0.002416  0.001619
# 2  0.003531  0.002285 -0.000420 -0.003738 -0.006706 -0.003148  0.000733
# 3 -0.001772 -0.001311  0.000388  0.000408 -0.000355  0.000998  0.001109
# 4  0.000087 -0.000272  0.001022  0.003126  0.002284  0.000885  0.001933
#
#         7         8         9    ...       118       119       120       121  \
# 0  0.006214  0.003307  0.007572  ...  0.001412 -0.001509  0.000060  0.000435
# 1  0.000981  0.000009 -0.000363  ... -0.000104 -0.000141  0.001333  0.001541
# 2  0.000668  0.002162 -0.000946  ...  0.000661  0.001853 -0.000268 -0.000394
# 3 -0.003149 -0.008882 -0.010483  ...  0.000458  0.002103  0.001358  0.000820
# 4  0.002270  0.002247  0.002175  ...  0.002529  0.003518 -0.000248 -0.002761
#
#         122       123       124       125       126       127
# ...

# %%
#just chack it is  X tran values
df_X = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt",
    sep=r'\s+',
    header=None
)
df_X.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.000181  0.010139  0.009276  0.005066  0.010810  0.004045  0.004757
# 1  0.001094  0.004550  0.002879  0.002247  0.003305  0.002416  0.001619
# 2  0.003531  0.002285 -0.000420 -0.003738 -0.006706 -0.003148  0.000733
# 3 -0.001772 -0.001311  0.000388  0.000408 -0.000355  0.000998  0.001109
# 4  0.000087 -0.000272  0.001022  0.003126  0.002284  0.000885  0.001933
#
#         7         8         9    ...       118       119       120       121  \
# 0  0.006214  0.003307  0.007572  ...  0.001412 -0.001509  0.000060  0.000435
# 1  0.000981  0.000009 -0.000363  ... -0.000104 -0.000141  0.001333  0.001541
# 2  0.000668  0.002162 -0.000946  ...  0.000661  0.001853 -0.000268 -0.000394
# 3 -0.003149 -0.008882 -0.010483  ...  0.000458  0.002103  0.001358  0.000820
# 4  0.002270  0.002247  0.002175  ...  0.002529  0.003518 -0.000248 -0.002761
#
#         122       123       124       125       126       127
# ...

# %% [markdown]
# To connect to your Google Drive, you can use the following code. This will prompt you to authorize Colab to access your Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# File Extract

# %%
import zipfile

zip_file = "/content/drive/MyDrive/Dataset_For_Bit/human+activity+recognition+using+smartphones (1).zip"  # Your ZIP file

with zipfile.ZipFile(zip_file, "r") as zip_ref:
    zip_ref.extractall("extracted_files")

print("ZIP extracted successfully!")
# Out:
# ZIP extracted successfully!

# %%
location = "/content/extracted_files/UCI HAR Dataset.zip"
with zipfile.ZipFile(location, "r") as zip_ref:
    zip_ref.extractall("extracted_files")

print("ZIP extracted successfully!")
# Out:
# ZIP extracted successfully!

# %% [markdown]
# data input as TXT

# %%
import pandas as pd
dataset = "/content/extracted_files/UCI HAR Dataset/test/Inertial Signals/body_acc_x_test.txt"
df =pd.read_csv(dataset,sep="\t")
df.head(10)
# Out:
#   1.1653150e-002  1.3109090e-002  1.1268850e-002  2.7830730e-002  2.3183500e-003 -1.8965500e-002 -6.1920230e-002 -9.4248130e-002 -7.9534200e-002 -7.0083760e-002 -1.9152480e-002 -2.2668950e-003 -3.0111470e-002 -1.1910260e-002 -1.5542110e-002 -1.6666170e-002 -6.6302790e-003 -2.3480930e-002 -1.7627590e-002 -2.1150170e-002 -3.2659070e-002 -2.2478410e-002 -1.0196890e-002 -3.1196910e-003 -1.6495820e-002 -2.0441880e-002 -2.7567620e-002 -5.5032500e-002 -5.7479710e-002 -4.7095990e-002 -2.8361690e-002 -1.7184890e-002 -7.3758860e-003  2.4778770e-002  2.3929340e-002  2.1248370e-002  9.6999630e-003 -3.5118900e-002 -1.0733260e-002  2.3672330e-002  1.4929500e-002  2.1906200e-002  5.0844080e-003 -1.3070070e-002 -7.9809120e-003 -1.2763990e-002 -9.8686730e-003 -3.6970220e-003  4.7806470e-003  7.9291720e-003 -5.4944340e-004 -9.1546860e-004 -4.9868180e-003  9.0750290e-003  3.3040610e-002  1.9763320e-002  1.0038920e-005 -1.7139270e-002 -2.9957720e-002 -9.4479730e-003  5.1335230e-003 -2.5121430e-003  3.21
# ...

# %%
import os

path = "/content/extracted_files/UCI HAR Dataset"

for root, dirs, files in os.walk(path):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /content/extracted_files/UCI HAR Dataset/.DS_Store
# /content/extracted_files/UCI HAR Dataset/README.txt
# /content/extracted_files/UCI HAR Dataset/activity_labels.txt
# /content/extracted_files/UCI HAR Dataset/features_info.txt
# /content/extracted_files/UCI HAR Dataset/features.txt
# /content/extracted_files/UCI HAR Dataset/train/subject_train.txt
# /content/extracted_files/UCI HAR Dataset/train/X_train.txt
# /content/extracted_files/UCI HAR Dataset/train/y_train.txt
# /content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_z_train.txt
# /content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt
# /content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_gyro_y_train.txt
# /content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_gyro_x_train.txt
# /content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_y_train.txt
# ...

# %%
#for total data set
import pandas as pd

X_train = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/X_train.txt",
    sep=r'\s+',
    header=None
)

print("The shape of thedataset",X_train.shape)
print("Train head ",X_train.head())
# Out:
# The shape of thedataset (7352, 561)
# Train head          0         1         2         3         4         5         6    \
# 0  0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1  0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2  0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3  0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4  0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
#
#         7         8         9    ...       551       552       553       554  \
# 0 -0.983185 -0.923527 -0.934724  ... -0.074323 -0.298676 -0.710304 -0.112754
# 1 -0.974914 -0.957686 -0.943068  ...  0.158075 -0.595051 -0.861499  0.053477
# 2 -0.963668 -0.977469 -0.938692  ...  0.414503 -0.390748 -0.760104 -0.118559
# 3 -0.982750 -0.989302 -0.938692  ...  0.404573 -0.117290 -0.482845 -0.036788
# 4 -0.979672 -0.990441 -0.942469  ...  0.087753 -0.351471 -0.699205  0.123320
#
# ...

# %%
#for total data set
import pandas as pd

X_train = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/test/X_test.txt",
    sep=r'\s+',
    header=None
)

print("The shape of thedataset",X_train.shape)
print("Train head ",X_train.head())
# Out:
# The shape of thedataset (2947, 561)
# Train head          0         1         2         3         4         5         6    \
# 0  0.257178 -0.023285 -0.014654 -0.938404 -0.920091 -0.667683 -0.952501
# 1  0.286027 -0.013163 -0.119083 -0.975415 -0.967458 -0.944958 -0.986799
# 2  0.275485 -0.026050 -0.118152 -0.993819 -0.969926 -0.962748 -0.994403
# 3  0.270298 -0.032614 -0.117520 -0.994743 -0.973268 -0.967091 -0.995274
# 4  0.274833 -0.027848 -0.129527 -0.993852 -0.967445 -0.978295 -0.994111
#
#         7         8         9    ...       551       552       553       554  \
# 0 -0.925249 -0.674302 -0.894088  ...  0.071645 -0.330370 -0.705974  0.006462
# 1 -0.968401 -0.945823 -0.894088  ... -0.401189 -0.121845 -0.594944 -0.083495
# 2 -0.970735 -0.963483 -0.939260  ...  0.062891 -0.190422 -0.640736 -0.034956
# 3 -0.974471 -0.968897 -0.938610  ...  0.116695 -0.344418 -0.736124 -0.017067
# 4 -0.965953 -0.977346 -0.938610  ... -0.121711 -0.534685 -0.846595 -0.002223
#
# ...

# %%
y_train = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/test/X_test.txt",
    header=None
)

print(y_train.head(1))
# Out:
#                                                    0
# 0    2.5717778e-001 -2.3285230e-002 -1.4653762e-0...

# %%
y_test = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/test/y_test.txt",
    header=None
)
#unipue values
print(y_test[0].unique())
# Out:
# [5 4 6 1 3 2]

# %%
# Load activity labels
activity_labels = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/activity_labels.txt",
    header=None,
    delim_whitespace=True
)

# Create mapping dictionary
label_map = dict(zip(activity_labels[0], activity_labels[1]))

# Apply mapping
y_test_named = y_test[0].map(label_map)
y_test_named.head()
print(y_test_named.unique())
# Out:
# ['STANDING' 'SITTING' 'LAYING' 'WALKING' 'WALKING_DOWNSTAIRS'
#  'WALKING_UPSTAIRS']
# /tmp/ipykernel_802/2310005255.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   activity_labels = pd.read_csv(

# %%
y_test_named.head()
# Out:
# 0    STANDING
# 1    STANDING
# 2    STANDING
# 3    STANDING
# 4    STANDING
# Name: 0, dtype: object

# %% [markdown]
# ## Files:
# ####  total_acc_x_train.txt, total_acc_y_train.txt, total_acc_z_train.txt
#
# #**Meaning**:
#  These are the raw accelerometer signals (body acceleration + gravity).
#
# Axes: Same as above (x, y, z).
#
# Use: Useful for recognizing postures (sitting, standing, lying) because gravity dominates when the body is still.

# %%
####

# %%
#just chack it is  X tran values
df_X = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt",
    sep=r'\s+',
    header=None
)
df_X.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.000181  0.010139  0.009276  0.005066  0.010810  0.004045  0.004757
# 1  0.001094  0.004550  0.002879  0.002247  0.003305  0.002416  0.001619
# 2  0.003531  0.002285 -0.000420 -0.003738 -0.006706 -0.003148  0.000733
# 3 -0.001772 -0.001311  0.000388  0.000408 -0.000355  0.000998  0.001109
# 4  0.000087 -0.000272  0.001022  0.003126  0.002284  0.000885  0.001933
#
#         7         8         9    ...       118       119       120       121  \
# 0  0.006214  0.003307  0.007572  ...  0.001412 -0.001509  0.000060  0.000435
# 1  0.000981  0.000009 -0.000363  ... -0.000104 -0.000141  0.001333  0.001541
# 2  0.000668  0.002162 -0.000946  ...  0.000661  0.001853 -0.000268 -0.000394
# 3 -0.003149 -0.008882 -0.010483  ...  0.000458  0.002103  0.001358  0.000820
# 4  0.002270  0.002247  0.002175  ...  0.002529  0.003518 -0.000248 -0.002761
#
#         122       123       124       125       126       127
# ...

# %% [markdown]
# #model Deployment

# %%
import pandas as pd

# Features
X_train = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/X_train.txt",
    delim_whitespace=True,
    header=None
)

X_test = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/test/X_test.txt",
    delim_whitespace=True,
    header=None
)

# Labels
y_train = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/train/y_train.txt",
    header=None
)

y_test = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/test/y_test.txt",
    header=None
)
# Out:
# /tmp/ipykernel_802/527162463.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   X_train = pd.read_csv(
# /tmp/ipykernel_802/527162463.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   X_test = pd.read_csv(

# %% [markdown]
# which Txt use for wha

# %%
import pandas as pd

features = pd.read_csv(
    "/content/extracted_files/UCI HAR Dataset/features.txt",
    sep=r"\s+",
    header=None,
    names=["index", "feature"]
)

print(features.head())
# Out:
#    index            feature
# 0      1  tBodyAcc-mean()-X
# 1      2  tBodyAcc-mean()-Y
# 2      3  tBodyAcc-mean()-Z
# 3      4   tBodyAcc-std()-X
# 4      5   tBodyAcc-std()-Y

# %%
X_train.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1  0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2  0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3  0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4  0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
#
#         7         8         9    ...       551       552       553       554  \
# 0 -0.983185 -0.923527 -0.934724  ... -0.074323 -0.298676 -0.710304 -0.112754
# 1 -0.974914 -0.957686 -0.943068  ...  0.158075 -0.595051 -0.861499  0.053477
# 2 -0.963668 -0.977469 -0.938692  ...  0.414503 -0.390748 -0.760104 -0.118559
# 3 -0.982750 -0.989302 -0.938692  ...  0.404573 -0.117290 -0.482845 -0.036788
# 4 -0.979672 -0.990441 -0.942469  ...  0.087753 -0.351471 -0.699205  0.123320
#
#         555       556       557       558       559       560
# ...

# %%
y_train.head()
# Out:
#    0
# 0  5
# 1  5
# 2  5
# 3  5
# 4  5

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 561 entries, 0 to 560
# dtypes: float64(561)
# memory usage: 31.5 MB

# %%
X_train.describe()
# Out:
#                0            1            2            3            4    \
# count  7352.000000  7352.000000  7352.000000  7352.000000  7352.000000
# mean      0.274488    -0.017695    -0.109141    -0.605438    -0.510938
# std       0.070261     0.040811     0.056635     0.448734     0.502645
# min      -1.000000    -1.000000    -1.000000    -1.000000    -0.999873
# 25%       0.262975    -0.024863    -0.120993    -0.992754    -0.978129
# 50%       0.277193    -0.017219    -0.108676    -0.946196    -0.851897
# 75%       0.288461    -0.010783    -0.097794    -0.242813    -0.034231
# max       1.000000     1.000000     1.000000     1.000000     0.916238
#
#                5            6            7            8            9    ...  \
# count  7352.000000  7352.000000  7352.000000  7352.000000  7352.000000  ...
# mean     -0.604754    -0.630512    -0.526907    -0.606150    -0.468604  ...
# std       0.418687     0.424073     0.485942     0.414122     0.544547  ...
# ...

# %%
X_train.shape
# Out:
# (7352, 561)

# %% [markdown]
# ### some imp point
# n_jobes =1
# it mean cpu used all core
# 2.   List item

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

n_trees = [200, 250, 300, 350, 375, 400, 400, 500]
test_acc = []

for n in n_trees:
    rf = RandomForestClassifier(
    criterion="log_loss",
    n_estimators=n,
    max_features="sqrt",
    max_depth=15,
    min_samples_leaf=4,
    random_state=42,
    n_jobs=1
    )

    rf.fit(X_train, y_train)

    y_pred = rf.predict(X_test)
    test_acc.append(accuracy_score(y_test, y_pred))

plt.plot(n_trees, test_acc, marker='o')
plt.xlabel("n_estimators")
plt.ylabel("Test Accuracy")
plt.title("Random Forest Performance")
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    criterion="log_loss",
    n_estimators=150,
    max_features="sqrt",
    max_depth=15,
    min_samples_leaf=4,
    random_state=42,
    n_jobs=1
)

rf.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=15, min_samples_leaf=4,
#                        n_estimators=150, n_jobs=1, random_state=42)

# %%
y_pred = rf.predict(X_test)

# %% [markdown]
# ## TEST THE MODEL WAS OVERFITED OR NOT

# %%
from sklearn.metrics import accuracy_score

# Training accuracy
train_pred = rf.predict(X_train)
train_acc = accuracy_score(y_train, train_pred)

# Testing accuracy
test_pred = rf.predict(X_test)
test_acc = accuracy_score(y_test, test_pred)

print("Train Accuracy:", train_acc)
print("Test Accuracy :", test_acc)
# Out:
# Train Accuracy: 1.0
# Test Accuracy : 0.9338310145911096

# %%
from sklearn.metrics import accuracy_score, classification_report

from sklearn.metrics import f1_score
print("Accuracy:", accuracy_score(y_test, y_pred))

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9338310145911096
#               precision    recall  f1-score   support
#
#            1       0.89      0.97      0.93       496
#            2       0.88      0.91      0.89       471
#            3       0.97      0.85      0.90       420
#            4       0.95      0.90      0.93       491
#            5       0.92      0.96      0.94       532
#            6       1.00      1.00      1.00       537
#
#     accuracy                           0.93      2947
#    macro avg       0.94      0.93      0.93      2947
# weighted avg       0.94      0.93      0.93      2947

# %%
activity_labels = {
    1: "WALKING",
    2: "WALKING_UPSTAIRS",
    3: "WALKING_DOWNSTAIRS",
    4: "SITTING",
    5: "STANDING",
    6: "LAYING"
}

# %%
X_test.iloc[::]
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.257178 -0.023285 -0.014654 -0.938404 -0.920091 -0.667683 -0.952501
# 1     0.286027 -0.013163 -0.119083 -0.975415 -0.967458 -0.944958 -0.986799
# 2     0.275485 -0.026050 -0.118152 -0.993819 -0.969926 -0.962748 -0.994403
# 3     0.270298 -0.032614 -0.117520 -0.994743 -0.973268 -0.967091 -0.995274
# 4     0.274833 -0.027848 -0.129527 -0.993852 -0.967445 -0.978295 -0.994111
# ...        ...       ...       ...       ...       ...       ...       ...
# 2942  0.310155 -0.053391 -0.099109 -0.287866 -0.140589 -0.215088 -0.356083
# 2943  0.363385 -0.039214 -0.105915 -0.305388  0.028148 -0.196373 -0.373540
# 2944  0.349966  0.030077 -0.115788 -0.329638 -0.042143 -0.250181 -0.388017
# 2945  0.237594  0.018467 -0.096499 -0.323114 -0.229775 -0.207574 -0.392380
# 2946  0.153627 -0.018437 -0.137018 -0.330046 -0.195253 -0.164339 -0.430974
#
# ...

# %%
for i in range (1,10):
 predicted_label = rf.predict([X_test.iloc[i]])[0]
 print(f"Predicted numerical label: {predicted_label}")
 print(f"Predicted activity: {activity_labels[predicted_label]}")
# Out:
# Predicted numerical label: 5
# Predicted activity: STANDING
# Predicted numerical label: 5
# Predicted activity: STANDING
# Predicted numerical label: 5
# Predicted activity: STANDING
# Predicted numerical label: 5
# Predicted activity: STANDING
# Predicted numerical label: 5
# Predicted activity: STANDING
# Predicted numerical label: 5
# Predicted activity: STANDING
# Predicted numerical label: 5
# Predicted activity: STANDING
# Predicted numerical label: 5
# Predicted activity: STANDING
# Predicted numerical label: 5
# Predicted activity: STANDING

# %%
pre = rf.predict([X_test.iloc[200]])[0]
for i in activity_labels:
  if i == pre:
    print(activity_labels[i])
# Out:
# SITTING
