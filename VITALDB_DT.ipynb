# %% [markdown]
# <a href="https://colab.research.google.com/github/BishalDas1010/BIT_project_TInyML/blob/main/VITALDB_DT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sensor That i have
# mpu6050 -
# MLX90614-temp
# MAX30102-heart

# %%
import pandas as pd

cases = pd.read_csv("https://api.vitaldb.net/cases")
print(cases.head())
# Out:
#    caseid  subjectid  casestart  caseend  anestart   aneend  opstart  opend  \
# 0       1       5955          0    11542      -552  10848.0     1668  10368
# 1       2       2487          0    15741     -1039  14921.0     1721  14621
# 2       3       2861          0     4394      -590   4210.0     1090   3010
# 3       4       1903          0    20990      -778  20222.0     2522  17822
# 4       5       4416          0    21531     -1009  22391.0     2591  20291
#
#       adm      dis  ...  intraop_colloid  intraop_ppf  intraop_mdz  \
# 0 -236220   627780  ...                0          120          0.0
# 1 -221160  1506840  ...                0          150          0.0
# 2 -218640    40560  ...                0            0          0.0
# 3 -201120   576480  ...                0           80          0.0
# 4  -67560  3734040  ...                0            0          0.0
#
#   intraop_ftn  intraop_rocu  intraop_vecu  intraop_eph  intraop_phe  \
# ...

# %%
# Out:
#    caseid  subjectid  casestart  caseend  anestart   aneend  opstart  opend  \
# 0       1       5955          0    11542      -552  10848.0     1668  10368
# 1       2       2487          0    15741     -1039  14921.0     1721  14621
# 2       3       2861          0     4394      -590   4210.0     1090   3010
# 3       4       1903          0    20990      -778  20222.0     2522  17822
# 4       5       4416          0    21531     -1009  22391.0     2591  20291
#
#       adm      dis  ...  intraop_colloid  intraop_ppf  intraop_mdz  \
# 0 -236220   627780  ...                0          120          0.0
# 1 -221160  1506840  ...                0          150          0.0
# 2 -218640    40560  ...                0            0          0.0
# 3 -201120   576480  ...                0           80          0.0
# 4  -67560  3734040  ...                0            0          0.0
#
#   intraop_ftn  intraop_rocu  intraop_vecu  intraop_eph  intraop_phe  \
# ...

# %%
cases.head()
# Out:
#    caseid  subjectid  casestart  caseend  anestart   aneend  opstart  opend  \
# 0       1       5955          0    11542      -552  10848.0     1668  10368
# 1       2       2487          0    15741     -1039  14921.0     1721  14621
# 2       3       2861          0     4394      -590   4210.0     1090   3010
# 3       4       1903          0    20990      -778  20222.0     2522  17822
# 4       5       4416          0    21531     -1009  22391.0     2591  20291
#
#       adm      dis  ...  intraop_colloid  intraop_ppf  intraop_mdz  \
# 0 -236220   627780  ...                0          120          0.0
# 1 -221160  1506840  ...                0          150          0.0
# 2 -218640    40560  ...                0            0          0.0
# 3 -201120   576480  ...                0           80          0.0
# 4  -67560  3734040  ...                0            0          0.0
#
#   intraop_ftn  intraop_rocu  intraop_vecu  intraop_eph  intraop_phe  \
# ...

# %%
trks = pd.read_csv("https://api.vitaldb.net/trks")
print(trks.head())
# Out:
#    caseid         tname                                       tid
# 0       1       BIS/BIS  fd869e25ba82a66cc95b38ed47110bf4f14bb368
# 1       1  BIS/EEG1_WAV  0aa685df768489a18a5e9f53af0d83bf60890c73
# 2       1  BIS/EEG2_WAV  ad13b2c39b19193c8ae4a2de4f8315f18d61a57e
# 3       1       BIS/EMG  2525603efe18d982764dbca457affe7a45e766a9
# 4       1       BIS/SEF  1c91aec859304840dec75acf4a35da78be0e8ef0

# %%
trks = pd.read_csv("https://api.vitaldb.net/trks")
print(trks.head())
# Out:
#    caseid         tname                                       tid
# 0       1       BIS/BIS  fd869e25ba82a66cc95b38ed47110bf4f14bb368
# 1       1  BIS/EEG1_WAV  0aa685df768489a18a5e9f53af0d83bf60890c73
# 2       1  BIS/EEG2_WAV  ad13b2c39b19193c8ae4a2de4f8315f18d61a57e
# 3       1       BIS/EMG  2525603efe18d982764dbca457affe7a45e766a9
# 4       1       BIS/SEF  1c91aec859304840dec75acf4a35da78be0e8ef0

# %%
import pandas as pd

# Download track list
trks = pd.read_csv("https://api.vitaldb.net/trks")

# Select one patient case
caseid = 1

case_tracks = trks[trks["caseid"] == caseid]

print(case_tracks["tname"].tolist())
# Out:
# ['BIS/BIS', 'BIS/EEG1_WAV', 'BIS/EEG2_WAV', 'BIS/EMG', 'BIS/SEF', 'BIS/SQI', 'BIS/SR', 'BIS/TOTPOW', 'Primus/AWP', 'Primus/CO2', 'Primus/COMPLIANCE', 'Primus/ETCO2', 'Primus/EXP_DES', 'Primus/EXP_SEVO', 'Primus/FEN2O', 'Primus/FEO2', 'Primus/FIN2O', 'Primus/FIO2', 'Primus/INCO2', 'Primus/INSP_DES', 'Primus/INSP_SEVO', 'Primus/MAC', 'Primus/MAWP_MBAR', 'Primus/MV', 'Primus/PAMB_MBAR', 'Primus/PEEP_MBAR', 'Primus/PIP_MBAR', 'Primus/PPLAT_MBAR', 'Primus/RR_CO2', 'Primus/SET_AGE', 'Primus/SET_FIO2', 'Primus/SET_FRESH_FLOW', 'Primus/SET_INSP_PAUSE', 'Primus/SET_INSP_TM', 'Primus/SET_INTER_PEEP', 'Primus/SET_PIP', 'Primus/SET_RR_IPPV', 'Primus/SET_TV_L', 'Primus/TV', 'Primus/VENT_LEAK', 'SNUADC/ART', 'SNUADC/ECG_II', 'SNUADC/ECG_V5', 'SNUADC/PLETH', 'Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP', 'Solar8000/BT', 'Solar8000/ETCO2', 'Solar8000/FEO2', 'Solar8000/FIO2', 'Solar8000/GAS2_EXPIRED', 'Solar8000/GAS2_INSPIRED', 'Solar8000/HR', 'Solar8000/INCO2', 'Solar8000/NIBP_DBP', 
# ...

# %%
hr_tid = case_tracks[case_tracks["tname"]=="Solar8000/HR"]["tid"].iloc[0]
sbp_tid = case_tracks[case_tracks["tname"]=="Solar8000/NIBP_SBP"]["tid"].iloc[0]
dbp_tid = case_tracks[case_tracks["tname"]=="Solar8000/NIBP_DBP"]["tid"].iloc[0]
spo2_tid = case_tracks[case_tracks["tname"]=="Solar8000/PLETH_SPO2"]["tid"].iloc[0]

# %%
# hr_df = pd.read_csv(f"https://api.vitaldb.net/{hr_tid}")
# sbp_df = pd.read_csv(f"https://api.vitaldb.net/{sbp_tid}")
# dbp_df = pd.read_csv(f"https://api.vitaldb.net/{dbp_tid}")

hr_df   = pd.read_csv(f"https://api.vitaldb.net/{hr_tid}")
sbp_df  = pd.read_csv(f"https://api.vitaldb.net/{sbp_tid}")
dbp_df  = pd.read_csv(f"https://api.vitaldb.net/{dbp_tid}")
spo2_df = pd.read_csv(f"https://api.vitaldb.net/{spo2_tid}")

# %%
trks = pd.read_csv("https://api.vitaldb.net/trks")

trks[trks["tname"].str.contains("spo2", case=False, na=False)]
# Out:
#         caseid                 tname                                       tid
# 59           1  Solar8000/PLETH_SPO2  b50ea1e4216b5c88f1b8d53c5f2c4eff2993edb6
# 137          2  Solar8000/PLETH_SPO2  6c3e76e7b0fab92b669b10dfc0de9b167dcc3be1
# 214          3  Solar8000/PLETH_SPO2  f38c86993d4b5b0b6b72966a03a7dd67436b7c04
# 293          4  Solar8000/PLETH_SPO2  16df233b3dc4da37c6b47ce12a13bc25d7eded6f
# 386          5  Solar8000/PLETH_SPO2  ae9d7d9dbe50ac304b1f49358ff89775df01b3fd
# ...        ...                   ...                                       ...
# 486132    6384  Solar8000/PLETH_SPO2  c189afd51ab15ea93c4fc6474abe7ff3ed8a61a1
# 486208    6385  Solar8000/PLETH_SPO2  8147ca97f94e072c16f34a0217dcae2cc75405da
# 486283    6386  Solar8000/PLETH_SPO2  0edf83988b2fb691e70bd2318cdc6fce61cd9774
# 486359    6387  Solar8000/PLETH_SPO2  572799a12bcb36b587dc2e013e1c1fb8049406fc
# 486438    6388  Solar8000/PLETH_SPO2  0e3b5bf5e1b7a51622725beea2b6412db734ce89
#
# [6386 rows x 3 columns]

# %%
hr_df.columns = ["time", "HR"]
sbp_df.columns = ["time", "SBP"]
dbp_df.columns = ["time", "DBP"]
spo2_df.columns = ["time", "SPO2"]

# %%
print(hr_df.head())
print(sbp_df.head())
print(dbp_df.head())
# Out:
#     time  HR
# 0  1.818  88
# 1  3.817  87
# 2  5.818  88
# 3  7.817  88
# 4  9.817  88
#       time  SBP
# 0   95.813  150
# 1   97.812  150
# 2   99.812  150
# 3  101.829  150
# 4  103.827  150
#       time  DBP
# 0   95.813   84
# 1   97.812   84
# 2   99.812   84
# 3  101.829   84
# 4  103.827   84

# %%
df = pd.merge_asof(
    hr_df.sort_values("time"),
    sbp_df.sort_values("time"),
    on="time"
)

df = pd.merge_asof(
    df.sort_values("time"),
    dbp_df.sort_values("time"),
    on="time"
)
df = pd.merge_asof(
    df.sort_values("time"),
    spo2_df.sort_values("time"),
    on="time"
)

# %%
df.head()
# Out:
#     time  HR  SBP  DBP  SPO2
# 0  1.818  88  NaN  NaN    96
# 1  3.817  87  NaN  NaN    96
# 2  5.818  88  NaN  NaN    97
# 3  7.817  88  NaN  NaN    96
# 4  9.817  88  NaN  NaN    96

# %%
import pandas as pd
"""
BT - BODY TEMPARATUR
HR - HEART RATE
SBP - SYSTOLIC BLOOD PRESSURE (SBP is the pressure in your arteries when the heart contracts (beats) and pumps blood)
DBP - DIASTOLIC BLOOD PRESSURE(DBP is the pressure in your arteries when the heart is relaxing between beats.)
"""
# Get the track ID for Body Temperature (BT)
bt_tid = case_tracks[case_tracks["tname"] == "Solar8000/BT"]["tid"].iloc[0]

# Load the Body Temperature data
bt_df = pd.read_csv(f"https://api.vitaldb.net/{bt_tid}")
spo2_df = pd.read_csv(f"https://api.vitaldb.net/{spo2_tid}")
print(bt_df)
# Rename columns
hr_df.columns = ["time", "HR"]
sbp_df.columns = ["time", "SBP"]
dbp_df.columns = ["time", "DBP"]
bt_df.columns = ["time", "BT"]
spo2_df.columns = ["time", "SPO2"]

# Sort by time
hr_df = hr_df.sort_values('time')
sbp_df = sbp_df.sort_values('time')
dbp_df = dbp_df.sort_values('time')
bt_df = bt_df.sort_values('time')
spo2_df = spo2_df.sort_values('time')

# Merge HR + SBP
df = pd.merge_asof(
    hr_df,
    sbp_df,
    on='time',
    direction='nearest'
)

# Merge DBP
df = pd.merge_asof(
    df,
    dbp_df,
    on='time',
    direction='nearest'
)

# Merge Temperature
df = pd.merge_asof(
    df,
    bt_df,
    on='time',
    direction='nearest'
)
#merge Temparture
df = pd.merge_asof(
    df,
    spo2_df,
    on='time',
    direction='nearest'
)
print(df.head())
print(df.shape)


print(df['BT'].nunique())
print(df['DBP'].nunique())

df['DBP'].unique()
df['SPO2'].unique()
# Out:
#            Time  Solar8000/BT
# 0         2.765          20.9
# 1         4.764          21.0
# 2         6.766          21.0
# 3         8.764          21.0
# 4        10.764          21.0
# ...         ...           ...
# 5755  11533.826          21.6
# 5756  11535.826          21.5
# 5757  11537.825          21.5
# 5758  11539.825          21.5
# 5759  11541.825          21.5
#
# [5760 rows x 2 columns]
#     time  HR  SBP  DBP    BT  SPO2
# 0  1.818  88  150   84  20.9    96
# 1  3.817  87  150   84  21.0    96
# 2  5.818  88  150   84  21.0    97
# 3  7.817  88  150   84  21.0    96
# 4  9.817  88  150   84  21.0    96
# (5455, 6)
# 122
# 8
# array([ 96,  97,  98,  99, 100])

# %%
df
# Out:
#            time   HR  SBP  DBP         BT  SPO2  HYPOXIA
# 0         1.818   88  150   84  20.900000    96        0
# 1         3.817   87  150   84  21.000000    96        0
# 2         5.818   88  150   84  21.000000    97        0
# 3         7.817   88  150   84  21.000000    96        0
# 4         9.817   88  150   84  21.000000    96        0
# ...         ...  ...  ...  ...        ...   ...      ...
# 5450  10932.800  103  199  100  24.900000   100        0
# 5451  10934.800  103  199  100  24.900000   100        0
# 5452  10936.800  103  199  100  24.800001    98        0
# 5453  10938.800  103  199  100  24.800001    98        0
# 5454  10940.800  103  199  100  24.800001    98        0
#
# [5455 rows x 7 columns]

# %%
# !pip install micromlgen
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for micromlgen: filename=micromlgen-1.1.28-py3-none-any.whl size=32152 sha256=7bea57a3ed02bf9f29fc06f9b4b43d0b0e1950812ba9fe383ef6d786bf05eba1
#   Stored in directory: /root/.cache/pip/wheels/16/02/8a/3a8b533174e4f7691a8fd72dab4493fb6819b79f8fcc1d18a6
# Successfully built micromlgen
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

model_df = df.copy()

# Handle missing values (critical for Isolation Forest)
print("Missing values before cleaning:")
print(model_df.isnull().sum())

# Option 1: Remove rows with any NaN (conservative)
# model_df = model_df.dropna()

# Option 2: Forward fill then backward fill (for time series)
model_df = model_df.fillna(method='ffill').fillna(method='bfill')

# Option 3: Interpolate (more sophisticated for time series)
# model_df = model_df.interpolate(method='linear')

print("\nMissing values after cleaning:")
print(model_df.isnull().sum())


# STEP 2: Feature Engineering (Optional but recommended)


# Add derived features that might help detect anomalies
model_df['HR_SBP_ratio'] = model_df['HR'] / model_df['SBP']
model_df['pulse_pressure'] = model_df['SBP'] - model_df['DBP']  # Normal: 30-50 mmHg
model_df['MAP'] = model_df['DBP'] + (model_df['pulse_pressure'] / 3)  # Mean Arterial Pressure

# Remove physiologically impossible values
model_df = model_df[
    (model_df['HR'].between(20, 250)) &
    (model_df['SBP'].between(50, 250)) &
    (model_df['DBP'].between(20, 150)) &
    (model_df['BT'].between(30, 42))  # Body temp in Celsius
]


# STEP 3: Select Features for Isolation Forest


# Basic features
feature_columns = ['HR', 'SBP', 'DBP', 'BT','SPO2']

# Extended features (if you created derived features)
# feature_columns = ['HR', 'SBP', 'DBP', 'BT', 'HR_SBP_ratio', 'pulse_pressure', 'MAP']

X = model_df[feature_columns].values


# STEP 4: Normalize the data


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


# STEP 5: Apply Isolation Fores

# Initialize and train Isolation Forest
# contamination: expected proportion of anomalies (adjust based on your expectation)
iso_forest = IsolationForest(
    contamination=0.1,        # Expect ~10% anomalies (adjust as needed)
    n_estimators=100,          # Number of trees
    max_samples='auto',        # Number of samples per tree
    random_state=42,
    n_jobs=-1                  # Use all available cores
)

# Fit the model
iso_forest.fit(X_scaled)

# Get predictions: -1 for anomalies, 1 for normal
predictions = iso_forest.predict(X_scaled)

# Get anomaly scores (more negative = more anomalous)
anomaly_scores = iso_forest.decision_function(X_scaled)
print(anomaly_scores)
# Add results to dataframe
model_df['anomaly'] = predictions
model_df['anomaly_score'] = anomaly_scores

# Convert to labels (0: normal, 1: anomaly)
model_df['anomaly_label'] = (model_df['anomaly'] == -1).astype(int)
# Out:
# Missing values before cleaning:
# time       0
# HR         0
# SBP        0
# DBP        0
# BT         0
# SPO2       0
# HYPOXIA    0
# dtype: int64
#
# Missing values after cleaning:
# time       0
# HR         0
# SBP        0
# DBP        0
# BT         0
# SPO2       0
# HYPOXIA    0
# dtype: int64
# /tmp/ipykernel_631/721132816.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   model_df = model_df.fillna(method='ffill').fillna(method='bfill')
# [-0.18075221 -0.180254   -0.16510926 ... -0.18685876 -0.19551524
#  -0.19551524]

# %%
model_df['anomaly_label'].unique()
# Out:
# array([1, 0])

# %%
(model_df['anomaly_label']==0).sum()
# Out:
# np.int64(4133)

# %%
zero_count = (model_df['anomaly_label'] == 0).sum()
one_count = (model_df['anomaly_label'] == 1).sum()

print("0 count:", zero_count)
print("1 count:", one_count)
# Out:
# 0 count: 4133
# 1 count: 451

# %%
print("\n" + "-"*50)
print("ISOLATION FOREST RESULTS")
print("-"*50)

print(f"Total samples: {len(model_df)}")
print(f"Normal samples: {(model_df['anomaly_label'] == 0).sum()} ({(model_df['anomaly_label'] == 0).sum()/len(model_df)*100:.1f})")
print(f"Anomalies detected: {(model_df['anomaly_label'] == 1).sum()} ({(model_df['anomaly_label'] == 1).sum()/len(model_df)*100:.1f})")

# Statistics by anomaly status
print("\nFeature statistics by class:")
print(model_df.groupby('anomaly_label')[feature_columns].describe())
# Out:
# --------------------------------------------------
# ISOLATION FOREST RESULTS
# --------------------------------------------------
# Total samples: 4584
# Normal samples: 4133 (90.2)
# Anomalies detected: 451 (9.8)
#
# Feature statistics by class:
#                    HR                                                        \
#                 count       mean        std   min   25%   50%    75%    max
# anomaly_label
# 0              4133.0  72.567626   8.346941  57.0  66.0  73.0   79.0   98.0
# 1               451.0  80.017738  18.786038  57.0  61.0  76.0  101.0  116.0
#
#                   SBP         ...         BT               SPO2             \
#                 count   mean  ...        75%        max   count       mean
# anomaly_label                 ...
# 0              4133.0  199.0  ...  36.000000  36.299999  4133.0  98.691749
# 1               451.0  199.0  ...  35.700001  36.200001   451.0  98.277162
#
#
#                     std   min   25%   50%    75%    max
# ...

# %%
plt.figure(figsize=(8, 5))

plt.hist(
    model_df['anomaly_score'],
    bins=50,
    edgecolor='black',
    alpha=0.7
)

plt.axvline(
    x=0,
    color='red',
    linestyle='--',
    linewidth=2,
    label='Decision Boundary'
)

plt.title('Distribution of Anomaly Scores')
plt.xlabel('Anomaly Score')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True, alpha=0.3)

plt.show()

# %%
model_df.describe()
# Out:
#                time           HR     SBP     DBP           BT         SPO2  \
# count   4584.000000  4584.000000  4584.0  4584.0  4584.000000  4584.000000
# mean    5865.333194    73.300611   199.0   100.0    35.697950    98.650960
# std     2647.101008    10.118906     0.0     0.0     0.488868     1.367266
# min     1281.930000    57.000000   199.0   100.0    30.000000    96.000000
# 25%     3573.620000    66.000000   199.0   100.0    35.500000    98.000000
# 50%     5865.325000    73.000000   199.0   100.0    35.700001    99.000000
# 75%     8157.050000    80.000000   199.0   100.0    36.000000   100.000000
# max    10448.700000   116.000000   199.0   100.0    36.299999   100.000000
#
#        HYPOXIA  HR_SBP_ratio  pulse_pressure     MAP      anomaly  \
# count   4584.0   4584.000000          4584.0  4584.0  4584.000000
# mean       0.0      0.368345            99.0   133.0     0.803229
# std        0.0      0.050849             0.0     0.0     0.595736
# ...

# %%
model_df
# Out:
#           time  HR  SBP  DBP         BT  SPO2  HYPOXIA  HR_SBP_ratio  \
# 634    1281.93  77  199  100  30.000000   100        0      0.386935
# 635    1283.93  77  199  100  30.600000   100        0      0.386935
# 636    1285.93  77  199  100  31.100000   100        0      0.386935
# 637    1287.93  77  199  100  31.600000   100        0      0.386935
# 638    1289.93  77  199  100  32.000000   100        0      0.386935
# ...        ...  ..  ...  ...        ...   ...      ...           ...
# 5213  10440.80  87  199  100  31.100000   100        0      0.437186
# 5214  10442.80  88  199  100  30.900000   100        0      0.442211
# 5215  10444.80  88  199  100  30.600000   100        0      0.442211
# 5216  10446.70  89  199  100  30.400000   100        0      0.447236
# 5217  10448.70  89  199  100  30.200001   100        0      0.447236
#
#       pulse_pressure    MAP  anomaly  anomaly_score  anomaly_label
# 634               99  133.0       -1      -0.180752              1
# ...

# %%
x=model_df[['HR','BT','SPO2']]
x
# Out:
#       HR         BT  SPO2
# 634   77  30.000000   100
# 635   77  30.600000   100
# 636   77  31.100000   100
# 637   77  31.600000   100
# 638   77  32.000000   100
# ...   ..        ...   ...
# 5213  87  31.100000   100
# 5214  88  30.900000   100
# 5215  88  30.600000   100
# 5216  89  30.400000   100
# 5217  89  30.200001   100
#
# [4584 rows x 3 columns]

# %%
y = model_df['anomaly_label']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score,classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model =  DecisionTreeClassifier(
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42
)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=5, min_samples_split=10,
#                        random_state=42)

# %%
model_pread = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score

accuracy = accuracy_score(y_test, model_pread)
f1 = f1_score(y_test, model_pread)

print(f"Model Accuracy: {accuracy:.4f}")
print(f"Model F1 Score: {f1:.4f}")
# Out:
# Model Accuracy: 0.9869
# Model F1 Score: 0.9231

# %%
train_acc = model.score(X_train, y_train)
test_acc = model.score(X_test, y_test)

print("Train:", train_acc)
print("Test :", test_acc)
# Out:
# Train: 0.9784565039541859
# Test : 0.9869138495092693

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report
)

# Predictions
y_pred = model.predict(X_test)

# Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# ROC-AUC
try:
    y_prob = model.predict_proba(X_test)
    roc_auc = roc_auc_score(
        y_test,
        y_prob,
        multi_class='ovr',
        average='weighted'
    )
except:
    roc_auc = "Not Available"

# Print Results
print(f"Accuracy (%) : {accuracy * 100:.2f}")
print(f"Precision    : {precision:.4f}")
print(f"Recall       : {recall:.4f}")
print(f"F1-Score     : {f1:.4f}")
print(f"ROC-AUC      : {roc_auc}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy (%) : 98.69
# Precision    : 0.9867
# Recall       : 0.9869
# F1-Score     : 0.9868
# ROC-AUC      : Not Available
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       837
#            1       0.95      0.90      0.92        80
#
#     accuracy                           0.99       917
#    macro avg       0.97      0.95      0.96       917
# weighted avg       0.99      0.99      0.99       917

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Probability of positive class
y_prob = model.predict_proba(X_test)[:, 1]

# ROC values
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# AUC Score
roc_auc = auc(fpr, tpr)

print("AUC Score:", roc_auc)

# Plot ROC Curve
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}")
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Decision Tree")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# AUC Score: 0.9893294504181601

# %%
# !pip install micromlgen
from micromlgen import port

with open("model.h", "w") as f:
    f.write(port(model))
